# %% [markdown]
# # [Estructuras de control de flujo](https://blog.hubspot.es/website/estructuras-de-control#:~:text=Las%20estructuras%20de%20control%20son,al%20menos%2C%20son%20muy%20parecidas.)
#
# Las estructuras de control de flujo son herramientas esenciales en la programación que permiten controlar cómo se ejecuta un programa en función de condiciones y decisiones. Estas estructuras ayudan a dirigir la secuencia de instrucciones y permiten que el programa tome diferentes caminos según las situaciones. Hay tres tipos principales de estructuras de control de flujo:

# %% [markdown]
# ## 1. **Estructuras de Control Secuencial:**
#    Esta es la forma más básica de control de flujo. Las instrucciones se ejecutan una tras otra, en orden, de arriba a abajo. No hay bifurcaciones ni repeticiones en la secuencia. Es útil para realizar tareas simples y lineales.
#
#    Ejemplo: Preparar una receta siguiendo los pasos uno a uno.
#
#       ```
#         INSTRUCCIÓN 1
#         INSTRUCCIÓN 2
#         .
#         .
#         .
#         INSTRUCCIÓN N
#       ```

# %% [markdown]
# ## 2. **Estructuras de Control de Decisión (Condicionales):**
#    Estas estructuras permiten al programa tomar decisiones basadas en condiciones. Si una condición es verdadera, el programa realiza una acción específica; de lo contrario, puede realizar otra acción.
#
#    ** Selectivas simples**
#     Evalúan un valor o una condición y determinan las instrucciones a ejecutar en caso de cumplirse la condición.
#     ```
#       SI <CONDICIÓN> ENTONCES
#       INSTRUCCIÓN/ES
#       FIN SI
#     ```
#   **Selectivas dobles**
#   Evalúan un valor o una condición. Determinan las instrucciones a ejecutar en caso de cumplirse la condición y también las instrucciones a ejecutar en caso de no cumplirse.
#   ```
#     SI <CONDICIÓN> ENTONCES
#       INSTRUCCIÓN/ES
#     SI NO
#       INSTRUCCIÓN/ES
#     FIN SI
#   ```
#    Ejemplo: Si está lloviendo, llevar un paraguas; si no, no llevarlo.
#
#   **Selectivas múltiples o anidadas**
#
#     Permiten combinar selectivas simples y dobles para crear estructuras y condiciones más complejas cuando el algoritmo en cuestión lo necesite.
#     ```
#       SI <CONDICIÓN 1> ENTONCES
#         INSTRUCCIÓN 1
#       SI NO
#         SI <CONDICIÓN 2> ENTONCES
#           INSTRUCCIÓN 2
#         SI NO
#           INSTRUCCIÓN 3
#         FIN SI
#       FIN SI
#     ```

# %% [markdown]
# ## 3. **Iterativas, de iteración, de repetición o repetitivas**
# Este tipo de estructuras de control nos sirven cuando necesitamos que se ejecute un conjunto específico de instrucciones en diversas ocasiones. La cantidad de veces que se repite dicho bloque de acciones puede ser estático o puede depender del valor de alguna variable o de alguna condición.
#
#   **Iterativas con cantidad fija de iteraciones**
#
#   Se utilizan cuando a priori se conoce la cantidad de ocasiones que debe repetirse un bloque de instrucciones. Normalmente, usan una variable de iteración o índice para contar la cantidad de repeticiones que se han realizado.
#   ```
#   PARA <VARIABLE> DESDE <VALOR1> HASTA <VALOR2> CON PASO <VALOR3> HACER
#     ACCIÓN/ES
#   FIN PARA
#   ```
#   El valor inicial <valor1> de la <variable> irá aumentando o disminuyendo según el paso <valor3> hasta llegar al valor <valor2>. Si no se especifica el valor de paso, se sobrentiende que el aumento es de uno en uno.
#
#   Iterativas con cantidad variable de iteraciones
# Se utilizan cuando la cantidad de ocasiones que debe repetirse un bloque de instrucciones está determinado por una condición. Por lo regular, existen dos variantes: repetir un bloque de instrucciones mientras se cumpla una condición o repartirlo hasta que se cumpla una condición.
# ```
#   MIENTRAS QUE <CONDICIÓN> HACER
#
#     ACCIÓN/ES A REPETIR
#
#   FIN MIENTRAS
#
#     REPETIR
#
#         ACCIÓN/ES
#
#     HASTA QUE <CONDICIÓN>
#   ```

# %%
list(range(2,20,3))
# Out:
# [2, 5, 8, 11, 14, 17]

# %%
for i in range(2,20,3):
  print(i**2)
# Out:
# 4
# 25
# 64
# 121
# 196
# 289

# %% [markdown]
# ## **¿Para qué se Usan las Estructuras de Control de Flujo?**
#
# Las estructuras de control de flujo son fundamentales en la programación por varias razones:
#
# 1. **Controlar la Lógica del Programa:** Permiten que un programa tome decisiones y realice diferentes acciones en función de condiciones específicas.
#
# 2. **Optimizar la Ejecución:** Ayudan a evitar la ejecución innecesaria de instrucciones y a dirigir el flujo del programa de manera eficiente.
#
# 3. **Automatizar Tareas Repetitivas:** Las estructuras de bucles permiten automatizar la repetición de instrucciones, lo que ahorra tiempo y reduce errores.
#
# 4. **Manejar Entrada de Usuario:** Permiten que el programa reaccione a la entrada del usuario y tome decisiones en función de esa entrada.
#
# 5. **Implementar Algoritmos Complejos:** Muchos algoritmos y soluciones requieren lógica de control de flujo para funcionar correctamente.
#
# En resumen, las estructuras de control de flujo son herramientas poderosas para dirigir y controlar la ejecución de programas, permitiendo que los desarrolladores creen aplicaciones más flexibles, interactivas y eficientes.

# %% [markdown]
# # [Explicación de Algoritmo y Diagrama de Flujo con Ejemplos](https://www.edrawsoft.com/es/explain-algorithm-flowchart.html)
#
# *Acceder al vinculo, super recomendado.*
#
# El algoritmo y el diagrama de flujo son dos tipos de herramientas para explicar el proceso de un programa. En esta página, se discuten las diferencias entre un algoritmo y un diagrama de flujo al igual que la forma de crear un diagrama de flujo para ilustrar el algoritmo de forma visual...

# %% [markdown]
# # Ejercicios
# 1. En una casa de cambio necesitan construir un programa tal que al dar como dato
# una cantidad expresada en dólares, convierta esa cantidad a pesos. Construye el
# diagrama de flujo y el pseudocódigo correspondiente.
# 2. Construye un diagrama de flujo y el correspondiente pseudocódigo que, al recibir como datos el costo de un artículo vendido y la cantidad de dinero entregada por el cliente, calcule e imprima el cambio que se debe entregar al cliente.
# 3. En las olimpíadas de invierno el tiempo que realizan los participantes en la competencia de velocidad en pista se mide en minutos, segundos y centésimas. La distancia que recorren se expresa en metros. Construye tanto un diagrama de flujo como el correspondiente pseudocódigo que calcule la velocidad de los participantes en kilómetros por hora de las diferentes competencias.
# 4. Construye un diagrama de flujo y el correspondiente pseudocódigo que, al recibir como dato el salario de un profesor de una universidad, calcule el incremento del salario de acuerdo con el siguiente criterio y escriba el nuevo salario del profesor
#
#       Salario < $18,000 ⇒ Incremento 12%
#
#       $18,000 <= Salario <= $30,000 ⇒ Incremento 8%.
#
#       $30,000 < Salario <= $50,000 ⇒ Incremento 7%.
#
#       $50,000 < Salario ⇒ Incremento 6%.
#
# 5. Construye un diagrama de flujo y el correspondiente pseudocódigo que determine,
# al recibir como datos dos números enteros, si un número es divisor de otro.
# 6. Se dice que un número N es primo si los únicos enteros positivos que lo dividen son exactamente 1 y N. Construye un diagrama de flujo y el correspondiente pseudocódigo que lea un número entero positivo NUM y escriba todos los números primos menores a dicho número.
# 7. Escribe un diagrama de flujo y el correspondiente pseudocódigo que, al recibir
# como dato un número entero N, obtenga el resultado de la siguiente serie:
# $$1^1 - 2^2 + 3^3 - \dots \pm N^N$$
# Dato: $N$ (variable de tipo entero que representa el número de términos de la serie).

# %% [markdown]
#     ```
#     Algoritmo veinte_numeros
# 	    Para i<-0 Hasta 20 Con Paso 1   Hacer
# 		    Escribir i
# 	    FinPara
#     FinAlgoritmo
#     ```
# ![Exampl.png](data:image/png;base64,...)
